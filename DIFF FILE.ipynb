# %%
# import datetime
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web

# %matplotlib inline

# Import Statsmodels

from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic

# %%
df = pd.read_csv('Variable.csv')

# %%
df = df.set_index('Date')
df
# Out:
#       Log Total Assets  Log Currency in Circulation ($ Bil)  \
# Date
# 2010            14.688                                6.887
# 2011            14.877                                6.972
# 2012            14.881                                7.053
# 2013            15.200                                7.115
# 2014            15.319                                7.190
# 2015            15.317                                7.255
# 2016            15.311                                7.313
# 2017            15.308                                7.381
# 2018            15.222                                7.442
# 2019            15.230                                7.492
#
#       Effective Federal Funds Rate (%)  Loss Function
# Date
# 2010                             0.183        -28.982
# 2011                             0.072        -20.251
# 2012                             0.165        -15.307
# 2013                             0.085         -7.407
# ...

# %%
X = df["Log Currency in Circulation ($ Bil)"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
    
    
X = df["Effective Federal Funds Rate (%)"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
    
    
X = df["Log Total Assets"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
    

    
    
X = df["Loss Function"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
# Out:
# ADF Statistic: -5.308291
# p-value: 0.000005
# Critical Values:
# 	1%: -4.939
# 	5%: -3.478
# 	10%: -2.844
# Reject Ho - Time Series is Stationary
# ADF Statistic: -4.236980
# p-value: 0.000570
# Critical Values:
# 	1%: -5.354
# 	5%: -3.646
# 	10%: -2.901
# Reject Ho - Time Series is Stationary
# ADF Statistic: -1.552158
# p-value: 0.507570
# Critical Values:
# 	1%: -5.354
# 	5%: -3.646
# 	10%: -2.901
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Statistic: -7.750514
# p-value: 0.000000
# Critical Values:
# 	1%: -5.354
# 	5%: -3.646
# 	10%: -2.901
# Reject Ho - Time Series is Stationary

# %%
data_new = df["Log Total Assets"].diff().dropna()
data_new
# Out:
# Date
# 2011    0.189
# 2012    0.004
# 2013    0.319
# 2014    0.119
# 2015   -0.002
# 2016   -0.006
# 2017   -0.003
# 2018   -0.086
# 2019    0.008
# Name: Log Total Assets, dtype: float64

# %%
X = data_new.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
# Out:
# ADF Statistic: -2.307012
# p-value: 0.169716
# Critical Values:
# 	1%: -4.665
# 	5%: -3.367
# 	10%: -2.803
# Failed to Reject Ho - Time Series is Non-Stationary

# %%
data_new1 = data_new.diff().dropna()
data_new1
# Out:
# Date
# 2012   -0.185
# 2013    0.315
# 2014   -0.200
# 2015   -0.121
# 2016   -0.004
# 2017    0.003
# 2018   -0.083
# 2019    0.094
# Name: Log Total Assets, dtype: float64

# %%
X = data_new1.values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
# Out:
# ADF Statistic: -4.528246
# p-value: 0.000175
# Critical Values:
# 	1%: -4.939
# 	5%: -3.478
# 	10%: -2.844
# Reject Ho - Time Series is Stationary

# %%
data_new1.to_csv("TA-DIFF-2")

# %%
df = pd.read_csv('Variable-3.csv')

# %%
df = df.set_index('Date')
df
# Out:
#       Log Total Assets  Log Currency in Circulation ($ Bil)  Loss Function
# Date
# 2019            15.230                                7.492          0.029
# 2018            15.222                                7.442          0.013
# 2017            15.308                                7.381         -0.088
# 2016            15.311                                7.313         -0.519
# 2015            15.317                                7.255         -1.759
# 2014            15.319                                7.190         -2.841
# 2013            15.200                                7.115         -7.407
# 2012            14.881                                7.053        -15.307
# 2011            14.877                                6.972        -20.251
# 2010            14.688                                6.887        -28.982

# %%
X = df["Log Currency in Circulation ($ Bil)"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
    
    
X = df["Log Total Assets"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
    

    
    
X = df["Loss Function"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
# Out:
# ADF Statistic: 4.901658
# p-value: 1.000000
# Critical Values:
# 	1%: -4.939
# 	5%: -3.478
# 	10%: -2.844
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Statistic: 0.647784
# p-value: 0.988736
# Critical Values:
# 	1%: -4.473
# 	5%: -3.290
# 	10%: -2.772
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Statistic: -1.281981
# p-value: 0.637375
# Critical Values:
# 	1%: -5.354
# 	5%: -3.646
# 	10%: -2.901
# Failed to Reject Ho - Time Series is Non-Stationary

# %%
data_new = df.diff().dropna()

# %%
X = data_new["Log Currency in Circulation ($ Bil)"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
    
    
X =data_new["Log Total Assets"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
    

    
    
X = data_new["Loss Function"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
# Out:
# ADF Statistic: 0.931565
# p-value: 0.993489
# Critical Values:
# 	1%: -5.354
# 	5%: -3.646
# 	10%: -2.901
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Statistic: -1.972991
# p-value: 0.298540
# Critical Values:
# 	1%: -4.665
# 	5%: -3.367
# 	10%: -2.803
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Statistic: 1.714693
# p-value: 0.998164
# Critical Values:
# 	1%: -5.354
# 	5%: -3.646
# 	10%: -2.901
# Failed to Reject Ho - Time Series is Non-Stationary

# %%
data_new1 = data_new.diff().dropna()

# %%
X = data_new1["Log Currency in Circulation ($ Bil)"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
    
    
X =data_new1["Log Total Assets"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
    

    
    
X = data_new1["Loss Function"].values
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]["5%"]:
    print ("Reject Ho - Time Series is Stationary")
else:
    print ("Failed to Reject Ho - Time Series is Non-Stationary")
# Out:
# ADF Statistic: -6.578905
# p-value: 0.000000
# Critical Values:
# 	1%: -5.354
# 	5%: -3.646
# 	10%: -2.901
# Reject Ho - Time Series is Stationary
# ADF Statistic: -2.733577
# p-value: 0.068406
# Critical Values:
# 	1%: -5.354
# 	5%: -3.646
# 	10%: -2.901
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Statistic: -0.420407
# p-value: 0.906635
# Critical Values:
# 	1%: -6.045
# 	5%: -3.929
# 	10%: -2.987
# Failed to Reject Ho - Time Series is Non-Stationary
