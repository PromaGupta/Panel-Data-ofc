# %%
import numpy as np
import pandas as pd
from scipy import stats
# set up panel data
pdata = pd.read_csv("CB data-10.csv", index_col = ["ID", "Year"],   
                   parse_dates = True)
pdata
# alternatively
# data = pd.read_csv("http://web.pdx.edu/~crkl/ceR/data/airline.txt", sep='\s+', nrows=90)
# Set data as panel data
# pdata = data.set_index(['I', 'T'], inplace=True)
# Out:
#                 SL   Market Capitalization    Market Cap Growth  \
# ID  Year
# TMP 2011-01-01   1              428,342,340             0.00500
#     2012-01-01   1              569,355,543             0.32900
#     2013-01-01   1              755,896,589             0.32800
#     2014-01-01   1              816,398,213             0.08000
#     2015-01-01   1              836,855,660             0.02500
# ...             ..                       ...                ...
# JPM 2015-01-01  10          243,000,000,000             0.03902
#     2016-01-01  10          309,000,000,000             0.27031
#     2017-01-01  10          371,000,000,000             0.20172
#     2018-01-01  10          325,000,000,000            -0.12512
#     2019-01-01  10          437,000,000,000             0.34686
#
#                 Debt / Equity Ratio  Debt / FCF Ratio  Return on Equity (ROE)  \
# ID  Year
# TMP 2011-01-01                1.277             5.532                   0.120
#     2012-01-01                0.840             6.747                   0.081
#     2013-01-01                1.175             6.940                   0.115
#     2014-01-01                1.108             7.867                   0.107
#     2015-01-01                1.379             9.279                   0.115
# ...                             ...               ...                     ...
# JPM 2015-01-01                1.931             6.506                   0.093
#     2016-01-01                1.949            22.635                   0.090
#     2017-01-01                1.935           -45.700                   0.088
#     2018-01-01                2.080            34.176                   0.119
#     2019-01-01                1.975           126.122                   0.132
#
#                 Return on Assets (ROA)  Return on Capital (ROIC)  \
# ID  Year
# TMP 2011-01-01                   0.011                     0.014
#     2012-01-01                   0.007                     0.010
#     2013-01-01                   0.010                     0.014
#     2014-01-01                   0.010                     0.014
#     2015-01-01                   0.011                     0.015
# ...                                ...                       ...
# JPM 2015-01-01                   0.009                     0.012
#     2016-01-01                   0.009                     0.013
#     2017-01-01                   0.009                     0.013
#     2018-01-01                   0.012                     0.014
#     2019-01-01                   0.013                     0.015
#
#                 Total Shareholders Return        TA        CC       FFR
# ID  Year
# TMP 2011-01-01                    0.03635  0.168670  0.078917 -0.074188
#     2012-01-01                    0.03683  0.045165  0.083758  0.038678
#     2013-01-01                    0.02997  0.190610  0.069855 -0.032918
#     2014-01-01                    0.02929  0.222585  0.069489 -0.019227
#     2015-01-01                    0.03027  0.034658  0.069810  0.045118
# ...                                   ...       ...       ...       ...
# JPM 2015-01-01                    0.03215  0.034658  0.069810  0.045118
#     2016-01-01                    0.04396 -0.003520  0.060822  0.259561
#     2017-01-01                    0.05020 -0.002286  0.064957  0.607770
#     2018-01-01                    0.07146 -0.041280  0.065968  0.831640
#     2019-01-01                    0.07809 -0.085689  0.049161  0.326158
#
# [90 rows x 12 columns]

# %%
column_names = {'Debt / Equity Ratio':'DE',
                'Debt / FCF Ratio':'DF',
                'Liquidity Ratio': 'LR',
                'Return on Equity (ROE)':'ROE',
               'Return on Assets (ROA)': 'ROA',
               'Return on Capital (ROIC)': 'ROIC',
               'Log Total Assets': 'TA',
               'Log Currency in Circulation ($ Bil)': 'CC',
               'Effective Federal Funds Rate (%)': 'FFR',
               'Loss Function': 'LF',
               'Total Shareholders Return':'SR'}

# rename columns
pdata =pdata.rename(columns = column_names)

# %%
pdata.describe()
# Out:
#               SL  Market Cap Growth         DE          DF        ROE  \
# count  90.000000          90.000000  90.000000   90.000000  90.000000
# mean    5.500000           0.123254   2.242478   10.954833   0.087200
# std     2.888373           0.259655   3.345739   56.742476   0.036497
# min     1.000000          -0.581110   0.113000 -233.177000  -0.030000
# 25%     3.000000          -0.050500   0.710500    3.714500   0.074000
# 50%     5.500000           0.082500   1.241500    6.951500   0.095500
# 75%     8.000000           0.283840   1.973750   15.428000   0.109750
# max    10.000000           1.220430  17.875000  349.065000   0.160000
#
#              ROA       ROIC         SR         TA         CC        FFR
# count  90.000000  90.000000  90.000000  90.000000  90.000000  90.000000
# mean    0.009444   0.012878   0.022263   0.058768   0.068082   0.220288
# std     0.004059   0.005396   0.058327   0.103613   0.009458   0.301403
# min    -0.002000   0.000000  -0.250160  -0.085689   0.049161  -0.074188
# 25%     0.008250   0.011250   0.016497  -0.003520   0.064957  -0.019227
# 50%     0.010500   0.014000   0.027185   0.034658   0.069489   0.045118
# 75%     0.012000   0.016000   0.046345   0.168670   0.069855   0.326158
# max     0.016000   0.022000   0.144960   0.222585   0.083758   0.831640

# %%
df = pdata

# %%
# Descriptive statistics
df.describe()
# Out:
#               SL  Market Cap Growth         DE          DF        ROE  \
# count  90.000000          90.000000  90.000000   90.000000  90.000000
# mean    5.500000           0.123254   2.242478   10.954833   0.087200
# std     2.888373           0.259655   3.345739   56.742476   0.036497
# min     1.000000          -0.581110   0.113000 -233.177000  -0.030000
# 25%     3.000000          -0.050500   0.710500    3.714500   0.074000
# 50%     5.500000           0.082500   1.241500    6.951500   0.095500
# 75%     8.000000           0.283840   1.973750   15.428000   0.109750
# max    10.000000           1.220430  17.875000  349.065000   0.160000
#
#              ROA       ROIC         SR         TA         CC        FFR
# count  90.000000  90.000000  90.000000  90.000000  90.000000  90.000000
# mean    0.009444   0.012878   0.022263   0.058768   0.068082   0.220288
# std     0.004059   0.005396   0.058327   0.103613   0.009458   0.301403
# min    -0.002000   0.000000  -0.250160  -0.085689   0.049161  -0.074188
# 25%     0.008250   0.011250   0.016497  -0.003520   0.064957  -0.019227
# 50%     0.010500   0.014000   0.027185   0.034658   0.069489   0.045118
# 75%     0.012000   0.016000   0.046345   0.168670   0.069855   0.326158
# max     0.016000   0.022000   0.144960   0.222585   0.083758   0.831640

# %%
# Pooled OLS estimator
from linearmodels import PooledOLS
pooled = PooledOLS.from_formula('ROE ~ 1 + DE + DF + TA + CC + FFR', df).fit()
print(pooled)
# Out:
#                           PooledOLS Estimation Summary
# ================================================================================
# Dep. Variable:                    ROE   R-squared:                        0.4112
# Estimator:                  PooledOLS   R-squared (Between):              0.6022
# No. Observations:                  90   R-squared (Within):              -0.2301
# Date:                Wed, May 11 2022   R-squared (Overall):              0.4112
# Time:                        22:16:36   Log-likelihood                    194.58
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      11.733
# Entities:                          10   P-value                           0.0000
# Avg Obs:                       9.0000   Distribution:                    F(5,84)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             11.733
#                                         P-value                           0.0000
# Time periods:                       9   Distribution:                    F(5,84)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.1094     0.0270     4.0581     0.0001      0.0558      0.1631
# CC            -0.1497     0.3989    -0.3752     0.7084     -0.9429      0.6436
# DE            -0.0066     0.0009    -7.1333     0.0000     -0.0085     -0.0048
# DF          5.753e-05  5.517e-05     1.0427     0.3001  -5.219e-05      0.0002
# FFR            0.0087     0.0148     0.5862     0.5593     -0.0207      0.0380
# TA             0.0047     0.0467     0.1017     0.9192     -0.0881      0.0975
# ==============================================================================

# %%
# Between estimator
from linearmodels import BetweenOLS
between = BetweenOLS.from_formula('ROE ~ 1 + DE + DF + TA + CC + FFR', df).fit()
print(between)
# Out:
#                          BetweenOLS Estimation Summary
# ================================================================================
# Dep. Variable:                    ROE   R-squared:                        0.0734
# Estimator:                 BetweenOLS   R-squared (Between):              0.0734
# No. Observations:                  54   R-squared (Within):               0.0011
# Date:                Thu, Apr 21 2022   R-squared (Overall):              0.0162
# Time:                        00:01:14   Log-likelihood                    122.82
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.7607
# Entities:                          54   P-value                           0.5826
# Avg Obs:                      10.0000   Distribution:                    F(5,48)
# Min Obs:                      10.0000
# Max Obs:                      10.0000   F-statistic (robust):             0.7607
#                                         P-value                           0.5826
# Time periods:                      10   Distribution:                    F(5,48)
# Avg Obs:                       54.000
# Min Obs:                       54.000
# Max Obs:                       54.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.0003  6.266e+04  5.193e-09     1.0000   -1.26e+05    1.26e+05
# CC             0.0023  1.219e+04  1.924e-07     1.0000  -2.451e+04   2.451e+04
# DE            -0.0044     0.0023    -1.9310     0.0594     -0.0089      0.0002
# DF            -0.0001     0.0004    -0.3806     0.7052     -0.0008      0.0006
# FFR            0.0002
# TA             0.0049     1647.2   2.99e-06     1.0000     -3311.9      3311.9
# ==============================================================================
# C:\Users\HP\anaconda3\lib\site-packages\linearmodels\panel\results.py:87: RuntimeWarning: invalid value encountered in sqrt
#   return Series(np.sqrt(np.diag(self.cov)), self._var_names, name="std_error")

# %%
# First differences estimator (without constant term)
from linearmodels import FirstDifferenceOLS
firstdiff = FirstDifferenceOLS.from_formula('ROE ~ DE + DF + TA + CC + FFR', df).fit()
print(firstdiff)
# Out:
#                      FirstDifferenceOLS Estimation Summary
# ================================================================================
# Dep. Variable:                    ROE   R-squared:                        0.0607
# Estimator:         FirstDifferenceOLS   R-squared (Between):             -0.5875
# No. Observations:                  80   R-squared (Within):               0.0480
# Date:                Wed, May 11 2022   R-squared (Overall):             -0.5660
# Time:                        22:16:49   Log-likelihood                    199.80
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.9690
# Entities:                          10   P-value                           0.4423
# Avg Obs:                       9.0000   Distribution:                    F(5,75)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             0.9690
#                                         P-value                           0.4423
# Time periods:                       9   Distribution:                    F(5,75)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# CC            -0.4298     0.3346    -1.2845     0.2029     -1.0964      0.2368
# DE            -0.0011     0.0032    -0.3496     0.7276     -0.0074      0.0052
# DF          2.372e-05  2.959e-05     0.8018     0.4252  -3.522e-05   8.267e-05
# FFR            0.0207     0.0113     1.8362     0.0703     -0.0018      0.0431
# TA             0.0138     0.0244     0.5646     0.5740     -0.0348      0.0623
# ==============================================================================

# %%
from linearmodels.panel.results import compare
res1 = {'Pooled':pooled,'Between':between,'firstdiff':firstdiff}
print(compare(res1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9608/855152109.py in <module>
#       1 from linearmodels.panel.results import compare
# ----> 2 res1 = {'Pooled':pooled,'Between':between,'firstdiff':firstdiff}
#       3 print(compare(res1))
#
# NameError: name 'between' is not defined

# %%
# Fixed effects or within estimator
# with constant inclued or not, will have the same results
# with constant term surpressed
from linearmodels import PanelOLS
fixed = PanelOLS.from_formula('ROE ~ DE + DF + TA + CC + FFR + EntityEffects', df).fit()
print(fixed)
# extract fixed effects
fixed.estimated_effects
fixed_effects = fixed.estimated_effects.unstack(level=0).values[0]
print(fixed_effects)
# F test for fixed effects versus OLS
print(fixed.f_pooled)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                    ROE   R-squared:                        0.1145
# Estimator:                   PanelOLS   R-squared (Between):             -0.5179
# No. Observations:                  90   R-squared (Within):               0.1145
# Date:                Wed, May 11 2022   R-squared (Overall):             -0.4965
# Time:                        22:16:53   Log-likelihood                    242.46
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.9400
# Entities:                          10   P-value                           0.0976
# Avg Obs:                       9.0000   Distribution:                    F(5,75)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             1.9400
#                                         P-value                           0.0976
# Time periods:                       9   Distribution:                    F(5,75)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# CC            -0.4072     0.2531    -1.6089     0.1118     -0.9113      0.0970
# DE             0.0017     0.0016     1.0486     0.2977     -0.0015      0.0048
# DF          2.391e-06  3.577e-05     0.0669     0.9469  -6.886e-05   7.364e-05
# FFR            0.0114     0.0092     1.2402     0.2188     -0.0069      0.0297
# TA             0.0012     0.0290     0.0402     0.9680     -0.0567      0.0590
# ==============================================================================
#
# F-test for Poolability: 15.814
# P-value: 0.0000
# Distribution: F(9,75)
#
# Included effects: Entity
# [0.07210051 0.01778001 0.12898019 0.12137678 0.11971729 0.11402322
#  0.13388914 0.14558036 0.13209701 0.10021303]
# Pooled F-statistic
# H0: Effects are zero
# Statistic: 15.8143
# P-value: 0.0000
# Distributed: F(9,75)

# %%
# with constant term included 
fixed1 = PanelOLS.from_formula('ROE ~ 1 + DE + DF + TA + CC + FFR + EntityEffects', df).fit()
print(fixed1)
# extract fixed effects
fixed1.estimated_effects
fixed1_effects = fixed1.params.Intercept + fixed1.estimated_effects.unstack(level=0).values[0]
print(fixed1_effects)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                    ROE   R-squared:                        0.1145
# Estimator:                   PanelOLS   R-squared (Between):             -0.2751
# No. Observations:                  90   R-squared (Within):               0.1145
# Date:                Wed, May 11 2022   R-squared (Overall):             -0.1857
# Time:                        22:16:55   Log-likelihood                    242.46
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.9400
# Entities:                          10   P-value                           0.0976
# Avg Obs:                       9.0000   Distribution:                    F(5,75)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             1.9400
#                                         P-value                           0.0976
# Time periods:                       9   Distribution:                    F(5,75)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.1086     0.0168     6.4756     0.0000      0.0752      0.1420
# CC            -0.4072     0.2531    -1.6089     0.1118     -0.9113      0.0970
# DE             0.0017     0.0016     1.0486     0.2977     -0.0015      0.0048
# DF          2.391e-06  3.577e-05     0.0669     0.9469  -6.886e-05   7.364e-05
# FFR            0.0114     0.0092     1.2402     0.2188     -0.0069      0.0297
# TA             0.0012     0.0290     0.0402     0.9680     -0.0567      0.0590
# ==============================================================================
#
# F-test for Poolability: 15.814
# P-value: 0.0000
# Distribution: F(9,75)
#
# Included effects: Entity
# [0.07210051 0.01778001 0.12898019 0.12137678 0.11971729 0.11402322
#  0.13388914 0.14558036 0.13209701 0.10021303]

# %%
# F test for fixed effects versus OLS
print(fixed1.f_pooled)
# Out:
# Pooled F-statistic
# H0: Effects are zero
# Statistic: 15.8143
# P-value: 0.0000
# Distributed: F(9,75)

# %%
# F test for fixed effects versus OLS
print(fixed1.f_pooled)
# Random effects estimator, constant term must be included
# should not have EntityEffects or TimeEffects in the formula
from linearmodels import RandomEffects
random = RandomEffects.from_formula('ROE ~ 1 + DE + DF + TA + CC + FFR', df).fit()
print(random)
# extract fixed effects
random.estimated_effects
random_effects = random.params.Intercept + random.estimated_effects.unstack(level=0).values[0]
print(random_effects)
print(random.variance_decomposition)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                    ROE   R-squared:                        0.0907
# Estimator:              RandomEffects   R-squared (Between):              0.0744
# No. Observations:                  90   R-squared (Within):               0.0929
# Date:                Wed, May 11 2022   R-squared (Overall):              0.0787
# Time:                        22:17:03   Log-likelihood                    235.32
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.6748
# Entities:                          10   P-value                           0.1496
# Avg Obs:                       9.0000   Distribution:                    F(5,84)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             1.6748
#                                         P-value                           0.1496
# Time periods:                       9   Distribution:                    F(5,84)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.1086     0.0195     5.5782     0.0000      0.0699      0.1474
# CC            -0.3360     0.2576    -1.3046     0.1956     -0.8482      0.1762
# DE            -0.0005     0.0014    -0.3279     0.7438     -0.0033      0.0024
# DF          8.657e-06  3.649e-05     0.2373     0.8130   -6.39e-05   8.122e-05
# FFR            0.0106     0.0094     1.1292     0.2620     -0.0081      0.0293
# TA             0.0011     0.0297     0.0369     0.9707     -0.0580      0.0602
# ==============================================================================
# [0.07912773 0.05202281 0.12224462 0.11601928 0.11752056 0.10965191
#  0.12733526 0.13714292 0.12583439 0.09945455]
# Effects                   0.000814
# Residual                  0.000321
# Percent due to Effects    0.716978
# Name: Variance Decomposition, dtype: float64

# %%
# compare fixed effects and random effects models
res2 = {'Pooled':pooled,'Fixed+1':fixed1,'Fixed':fixed,'Random':random}
print(compare(res2))

effects = pd.DataFrame({'Fixed Effects':fixed_effects,'Random Effects':random_effects},
                       index=pdata.index.levels[0])
print(effects)
# Out:
#                                    Model Comparison
# ======================================================================================
#                                 Pooled        Fixed+1          Fixed            Random
# --------------------------------------------------------------------------------------
# Dep. Variable                      ROE            ROE            ROE               ROE
# Estimator                    PooledOLS       PanelOLS       PanelOLS     RandomEffects
# No. Observations                    90             90             90                90
# Cov. Est.                   Unadjusted     Unadjusted     Unadjusted        Unadjusted
# R-squared                       0.4112         0.1145         0.1145            0.0907
# R-Squared (Within)             -0.2301         0.1145         0.1145            0.0929
# R-Squared (Between)             0.6022        -0.2751        -0.5179            0.0744
# R-Squared (Overall)             0.4112        -0.1857        -0.4965            0.0787
# F-statistic                     11.733         1.9400         1.9400            1.6748
# P-value (F-stat)                0.0000         0.0976         0.0976            0.1496
# =====================     ============   ============   ============   ===============
# Intercept                       0.1094         0.1086                           0.1086
#                               (4.0581)       (6.4756)                         (5.5782)
# CC                             -0.1497        -0.4072        -0.4072           -0.3360
#                              (-0.3752)      (-1.6089)      (-1.6089)         (-1.3046)
# DE                             -0.0066         0.0017         0.0017           -0.0005
#                              (-7.1333)       (1.0486)       (1.0486)         (-0.3279)
# DF                           5.753e-05      2.391e-06      2.391e-06         8.657e-06
#                               (1.0427)       (0.0669)       (0.0669)          (0.2373)
# FFR                             0.0087         0.0114         0.0114            0.0106
#                               (0.5862)       (1.2402)       (1.2402)          (1.1292)
# TA                              0.0047         0.0012         0.0012            0.0011
#                               (0.1017)       (0.0402)       (0.0402)          (0.0369)
# ======================= ============== ============== ============== =================
# Effects                                        Entity         Entity
# --------------------------------------------------------------------------------------
#
# T-stats reported in parentheses
#       Fixed Effects  Random Effects
# ID
# BAC        0.072101        0.079128
# BCS        0.017780        0.052023
# CTBI       0.128980        0.122245
# INDB       0.121377        0.116019
# JPM        0.119717        0.117521
# THFF       0.114023        0.109652
# TMP        0.133889        0.127335
# WASH       0.145580        0.137143
# WFC        0.132097        0.125834
# WSBC       0.100213        0.099455

# %%
# LM test for random effects versus OLS
n = pdata.index.levels[0].size
T = pdata.index.levels[1].size
D = np.kron(np.eye(n), np.ones(T)).T
e = pooled.resids
LM = (e.dot(D).dot(D.T).dot(e) / e.dot(e) - 1) ** 2 * n * T / 2 / (T - 1)
LM_pvalue = stats.chi2(1).sf(LM)
print("LM Test: chisq = {0}, df = 1, p-value = {1}".format(LM, LM_pvalue))
# Out:
# LM Test: chisq = 76.39581200397889, df = 1, p-value = 2.3214306731599476e-18

# %%
# Hausman test for fixed versus random effects model
# null hypothesis: random effects model
psi = fixed.cov - random.cov.iloc[1:,1:]
diff = fixed.params - random.params[1:]
# psi = fixed1.cov.iloc[1:,1:] - random.cov.iloc[1:,1:]
# diff = fixed1.params[1:] - random.params[1:]
W = diff.dot(np.linalg.inv(psi)).dot(diff)
dof = random.params.size -1
pvalue = stats.chi2(dof).sf(W)
print("Hausman Test: chisq = {0}, df = {1}, p-value = {2}".format(W, dof, pvalue))
# Out:
# Hausman Test: chisq = 9.752405656128088, df = 5, p-value = 0.08256250770267884

# %%
# panel robust hetero cov
fixed_robust = PanelOLS.from_formula('ROE ~ 1 + DE + DF + TA + CC + FFR + EntityEffects', df).fit(cov_type='clustered',cluster_entity=True)
print(fixed_robust)
random_robust = RandomEffects.from_formula('ROE ~ 1 + DE + DF + TA + CC + FFR', df).fit(cov_type='clustered',cluster_entity=True)
print(random_robust)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                    ROE   R-squared:                        0.1145
# Estimator:                   PanelOLS   R-squared (Between):             -0.2751
# No. Observations:                  90   R-squared (Within):               0.1145
# Date:                Wed, May 11 2022   R-squared (Overall):             -0.1857
# Time:                        22:17:40   Log-likelihood                    242.46
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.9400
# Entities:                          10   P-value                           0.0976
# Avg Obs:                       9.0000   Distribution:                    F(5,75)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             1.7534
#                                         P-value                           0.1329
# Time periods:                       9   Distribution:                    F(5,75)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.1086     0.0153     7.0802     0.0000      0.0780      0.1391
# CC            -0.4072     0.2559    -1.5911     0.1158     -0.9169      0.1026
# DE             0.0017     0.0012     1.3818     0.1711     -0.0007      0.0041
# DF          2.391e-06  2.454e-05     0.0974     0.9226   -4.65e-05   5.128e-05
# FFR            0.0114     0.0056     2.0232     0.0466      0.0002      0.0226
# TA             0.0012     0.0164     0.0712     0.9434     -0.0315      0.0338
# ==============================================================================
#
# F-test for Poolability: 15.814
# P-value: 0.0000
# Distribution: F(9,75)
#
# Included effects: Entity
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                    ROE   R-squared:                        0.0907
# Estimator:              RandomEffects   R-squared (Between):              0.0744
# No. Observations:                  90   R-squared (Within):               0.0929
# Date:                Wed, May 11 2022   R-squared (Overall):              0.0787
# Time:                        22:17:40   Log-likelihood                    235.32
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.6748
# Entities:                          10   P-value                           0.1496
# Avg Obs:                       9.0000   Distribution:                    F(5,84)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             1.0674
#                                         P-value                           0.3843
# Time periods:                       9   Distribution:                    F(5,84)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.1086     0.0115     9.4253     0.0000      0.0857      0.1316
# CC            -0.3360     0.2238    -1.5013     0.1370     -0.7811      0.1091
# DE            -0.0005     0.0009    -0.5225     0.6027     -0.0023      0.0013
# DF          8.657e-06  2.398e-05     0.3609     0.7191  -3.904e-05   5.635e-05
# FFR            0.0106     0.0061     1.7367     0.0861     -0.0015      0.0228
# TA             0.0011     0.0163     0.0673     0.9465     -0.0313      0.0334
# ==============================================================================

# %%
# compare fixed effects and random effects models
res3 = {'Fixed (Panel-Robust)':fixed_robust,'Random (Panel-Robust)':random_robust}
print(compare(res3))
# Out:
#                          Model Comparison
# ==================================================================
#                         Fixed (Panel-Robust) Random (Panel-Robust)
# ------------------------------------------------------------------
# Dep. Variable                            ROE                   ROE
# Estimator                           PanelOLS         RandomEffects
# No. Observations                         540                   540
# Cov. Est.                          Clustered             Clustered
# R-squared                             0.1099                0.0837
# R-Squared (Within)                    0.1099                0.0926
# R-Squared (Between)                  -0.7870               -0.0090
# R-Squared (Overall)                  -0.0770                0.0714
# F-statistic                           11.879                9.7559
# P-value (F-stat)                      0.0000                0.0000
# =====================           ============       ===============
# Intercept                            -0.7423               -0.6232
#                                    (-2.2216)             (-1.8476)
# CC                                    0.0849                0.0746
#                                     (3.4005)              (3.0025)
# DE                                    0.0101                0.0003
#                                     (2.7018)              (0.0951)
# DF                                -6.722e-07             1.866e-05
#                                    (-0.0158)              (0.5273)
# FFR                                  -0.0022               -0.0019
#                                    (-0.5541)             (-0.4854)
# TA                                    0.0136                0.0114
#                                     (0.7713)              (0.6357)
# =======================       ==============     =================
# Effects                               Entity
# ------------------------------------------------------------------
#
# T-stats reported in parentheses

# %% [markdown]
# ## DE

# %%
pdata = pd.read_csv("CB data-10.csv", index_col = ["ID", "Year"],   
                   parse_dates = True)
column_names = {'Debt / Equity Ratio':'DE',
                'Debt / FCF Ratio':'DF',
                'Liquidity Ratio': 'LR',
                'Return on Equity (ROE)':'ROE',
               'Return on Assets (ROA)': 'ROA',
               'Return on Capital (ROIC)': 'ROIC',
               'Log Total Assets': 'TA',
               'Log Currency in Circulation ($ Bil)': 'CC',
               'Effective Federal Funds Rate (%)': 'FFR',
               'Loss Function': 'LF',
               'Total Shareholders Return':'SR'}

# rename columns
pdata =pdata.rename(columns = column_names)

# %%
df = pdata
# Pooled OLS estimator
from linearmodels import PooledOLS
pooled = PooledOLS.from_formula('DE ~ 1 + ROE + TA + CC + FFR', df).fit()
print(pooled)
# Out:
#                           PooledOLS Estimation Summary
# ================================================================================
# Dep. Variable:                     DE   R-squared:                        0.3970
# Estimator:                  PooledOLS   R-squared (Between):              0.5701
# No. Observations:                  90   R-squared (Within):              -0.6645
# Date:                Wed, May 11 2022   R-squared (Overall):              0.3970
# Time:                        22:26:24   Log-likelihood                   -213.13
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      13.992
# Entities:                          10   P-value                           0.0000
# Avg Obs:                       9.0000   Distribution:                    F(4,85)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             13.992
#                                         P-value                           0.0000
# Time periods:                       9   Distribution:                    F(4,85)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      6.2068     2.6253     2.3642     0.0203      0.9870      11.427
# CC             15.068     36.599     0.4117     0.6816     -57.701      87.837
# FFR            0.2180     1.3619     0.1601     0.8732     -2.4898      2.9259
# ROE           -57.516     7.8124    -7.3621     0.0000     -73.049     -41.982
# TA            -0.3894     4.2553    -0.0915     0.9273     -8.8502      8.0713
# ==============================================================================

# %%
# Between estimator
from linearmodels import BetweenOLS
between = BetweenOLS.from_formula('DE ~ 1 + ROE + TA + CC + FFR', df).fit()
print(between)
# Out:
#                          BetweenOLS Estimation Summary
# ================================================================================
# Dep. Variable:                     DE   R-squared:                        0.6035
# Estimator:                 BetweenOLS   R-squared (Between):              0.6035
# No. Observations:                  10   R-squared (Within):              -1.2365
# Date:                Wed, May 11 2022   R-squared (Overall):              0.3456
# Time:                        22:27:06   Log-likelihood                   -20.829
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.9029
# Entities:                          10   P-value                           0.2483
# Avg Obs:                       9.0000   Distribution:                     F(4,5)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             1.9029
#                                         P-value                           0.2483
# Time periods:                       9   Distribution:                     F(4,5)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      8.3310  1.852e+07  4.498e-07     1.0000  -4.761e+07   4.761e+07
# CC             0.5672   5.18e+08  1.095e-09     1.0000  -1.331e+09   1.331e+09
# FFR            1.8352
# ROE           -75.232     27.268    -2.7589     0.0399     -145.33     -5.1363
# TA             0.4896
# ==============================================================================
# C:\Users\HP\anaconda3\lib\site-packages\linearmodels\panel\results.py:87: RuntimeWarning: invalid value encountered in sqrt
#   return Series(np.sqrt(np.diag(self.cov)), self._var_names, name="std_error")

# %%
# First differences estimator (without constant term)
from linearmodels import FirstDifferenceOLS
firstdiff = FirstDifferenceOLS.from_formula('DE ~  ROE + TA + CC + FFR', df).fit()
print(firstdiff)
# Out:
#                      FirstDifferenceOLS Estimation Summary
# ================================================================================
# Dep. Variable:                     DE   R-squared:                        0.0353
# Estimator:         FirstDifferenceOLS   R-squared (Between):              0.2653
# No. Observations:                  80   R-squared (Within):               0.0686
# Date:                Wed, May 11 2022   R-squared (Overall):              0.2464
# Time:                        22:28:01   Log-likelihood                   -88.261
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      0.6956
# Entities:                          10   P-value                           0.5973
# Avg Obs:                       9.0000   Distribution:                    F(4,76)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             0.6956
#                                         P-value                           0.5973
# Time periods:                       9   Distribution:                    F(4,76)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# CC             17.846     12.132     1.4710     0.1454     -6.3164      42.009
# FFR           -0.1648     0.4186    -0.3936     0.6950     -0.9985      0.6690
# ROE           -1.6790     4.1789    -0.4018     0.6890     -10.002      6.6440
# TA             0.2979     0.8757     0.3402     0.7346     -1.4461      2.0420
# ==============================================================================

# %%
from linearmodels.panel.results import compare
res1 = {'Pooled':pooled,'Between':between,'firstdiff':firstdiff}
print(compare(res1))
# Fixed effects or within estimator
# with constant inclued or not, will have the same results
# with constant term surpressed
from linearmodels import PanelOLS
fixed = PanelOLS.from_formula('DE ~  ROE + TA + CC + FFR + EntityEffects', df).fit()
print(fixed)
# extract fixed effects
fixed.estimated_effects
fixed_effects = fixed.estimated_effects.unstack(level=0).values[0]
print(fixed_effects)
# F test for fixed effects versus OLS
print(fixed.f_pooled)
# Out:
#                            Model Comparison
# =====================================================================
#                             Pooled       Between            firstdiff
# ---------------------------------------------------------------------
# Dep. Variable                   DE            DE                   DE
# Estimator                PooledOLS    BetweenOLS   FirstDifferenceOLS
# No. Observations                90            10                   80
# Cov. Est.               Unadjusted    Unadjusted           Unadjusted
# R-squared                   0.3970        0.6035               0.0353
# R-Squared (Within)         -0.6645       -1.2365               0.0686
# R-Squared (Between)         0.5701        0.6035               0.2653
# R-Squared (Overall)         0.3970        0.3456               0.2464
# F-statistic                 13.992        1.9029               0.6956
# P-value (F-stat)            0.0000        0.2483               0.5973
# ===================== ============ ============= ====================
# Intercept                   6.2068        8.3310
#                           (2.3642)   (4.498e-07)
# CC                          15.068        0.5672               17.846
#                           (0.4117)   (1.095e-09)             (1.4710)
# FFR                         0.2180        1.8352              -0.1648
#                           (0.1601)                          (-0.3936)
# ROE                        -57.516       -75.232              -1.6790
#                          (-7.3621)     (-2.7589)            (-0.4018)
# TA                         -0.3894        0.4896               0.2979
#                          (-0.0915)                           (0.3402)
# ---------------------------------------------------------------------
#
# T-stats reported in parentheses
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                     DE   R-squared:                        0.1027
# Estimator:                   PanelOLS   R-squared (Between):              0.1840
# No. Observations:                  90   R-squared (Within):               0.1027
# Date:                Wed, May 11 2022   R-squared (Overall):              0.1761
# Time:                        22:29:04   Log-likelihood                   -142.60
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      2.1744
# Entities:                          10   P-value                           0.0798
# Avg Obs:                       9.0000   Distribution:                    F(4,76)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             2.1744
#                                         P-value                           0.0798
# Time periods:                       9   Distribution:                    F(4,76)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# CC             38.060     17.858     2.1313     0.0363      2.4932      73.627
# FFR           -0.4912     0.6624    -0.7414     0.4607     -1.8105      0.8282
# ROE            8.6866     8.2125     1.0577     0.2935     -7.6700      25.043
# TA            -0.4027     2.0553    -0.1959     0.8452     -4.4962      3.6908
# ==============================================================================
#
# F-test for Poolability: 32.040
# P-value: 0.0000
# Distribution: F(9,76)
#
# Included effects: Entity
# [-0.95394     8.75090555 -2.68288165 -2.72043062 -1.02526975 -2.96823663
#  -2.02218841 -1.8153575  -1.92812043 -2.37786689]
# Pooled F-statistic
# H0: Effects are zero
# Statistic: 32.0399
# P-value: 0.0000
# Distributed: F(9,76)

# %%
# with constant term included 
fixed1 = PanelOLS.from_formula('DE ~ 1 + ROE + TA + CC + FFR + EntityEffects', df).fit()
print(fixed1)
# extract fixed effects
fixed1.estimated_effects
fixed1_effects = fixed1.params.Intercept + fixed1.estimated_effects.unstack(level=0).values[0]
print(fixed1_effects)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                     DE   R-squared:                        0.1027
# Estimator:                   PanelOLS   R-squared (Between):             -0.1474
# No. Observations:                  90   R-squared (Within):               0.1027
# Date:                Wed, May 11 2022   R-squared (Overall):             -0.1124
# Time:                        22:30:11   Log-likelihood                   -142.60
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      2.1744
# Entities:                          10   P-value                           0.0798
# Avg Obs:                       9.0000   Distribution:                    F(4,76)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             2.1744
#                                         P-value                           0.0798
# Time periods:                       9   Distribution:                    F(4,76)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept     -0.9743     1.4946    -0.6519     0.5164     -3.9511      2.0025
# CC             38.060     17.858     2.1313     0.0363      2.4932      73.627
# FFR           -0.4912     0.6624    -0.7414     0.4607     -1.8105      0.8282
# ROE            8.6866     8.2125     1.0577     0.2935     -7.6700      25.043
# TA            -0.4027     2.0553    -0.1959     0.8452     -4.4962      3.6908
# ==============================================================================
#
# F-test for Poolability: 32.040
# P-value: 0.0000
# Distribution: F(9,76)
#
# Included effects: Entity
# [-0.95394     8.75090555 -2.68288165 -2.72043062 -1.02526975 -2.96823663
#  -2.02218841 -1.8153575  -1.92812043 -2.37786689]

# %%
# F test for fixed effects versus OLS
print(fixed1.f_pooled)
# Out:
# Pooled F-statistic
# H0: Effects are zero
# Statistic: 32.0399
# P-value: 0.0000
# Distributed: F(9,76)

# %%
# Random effects estimator, constant term must be included
# should not have EntityEffects or TimeEffects in the formula
from linearmodels import RandomEffects
random = RandomEffects.from_formula('DE ~ 1 + ROE + TA + CC + FFR', df).fit()
print(random)
# extract fixed effects
random.estimated_effects
random_effects = random.params.Intercept + random.estimated_effects.unstack(level=0).values[0]
print(random_effects)
print(random.variance_decomposition)
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                     DE   R-squared:                        0.0784
# Estimator:              RandomEffects   R-squared (Between):             -0.0277
# No. Observations:                  90   R-squared (Within):               0.0942
# Date:                Wed, May 11 2022   R-squared (Overall):             -0.0106
# Time:                        22:31:19   Log-likelihood                   -150.05
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      1.8069
# Entities:                          10   P-value                           0.1350
# Avg Obs:                       9.0000   Distribution:                    F(4,85)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             1.8069
#                                         P-value                           0.1350
# Time periods:                       9   Distribution:                    F(4,85)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept     -0.2173     1.7505    -0.1241     0.9015     -3.6978      3.2632
# CC             35.636     18.324     1.9448     0.0551     -0.7961      72.069
# FFR           -0.4164     0.6799    -0.6124     0.5419     -1.7683      0.9355
# ROE            1.7077     8.0773     0.2114     0.8331     -14.352      17.768
# TA            -0.4013     2.1112    -0.1901     0.8497     -4.5989      3.7963
# ==============================================================================
# [-0.41795777  7.54642167 -1.5548072  -1.63232906 -0.1940719  -1.88800473
#  -0.96104557 -0.71443117 -0.89079789 -1.46620388]
# Effects                   7.363747
# Residual                  1.648705
# Percent due to Effects    0.817064
# Name: Variance Decomposition, dtype: float64

# %%
# compare fixed effects and random effects models
res2 = {'Pooled':pooled,'Fixed+1':fixed1,'Fixed':fixed,'Random':random}
print(compare(res2))

effects = pd.DataFrame({'Fixed Effects':fixed_effects,'Random Effects':random_effects},
                       index=pdata.index.levels[0])
print(effects)
# Out:
#                                    Model Comparison
# ======================================================================================
#                                 Pooled        Fixed+1          Fixed            Random
# --------------------------------------------------------------------------------------
# Dep. Variable                       DE             DE             DE                DE
# Estimator                    PooledOLS       PanelOLS       PanelOLS     RandomEffects
# No. Observations                    90             90             90                90
# Cov. Est.                   Unadjusted     Unadjusted     Unadjusted        Unadjusted
# R-squared                       0.3970         0.1027         0.1027            0.0784
# R-Squared (Within)             -0.6645         0.1027         0.1027            0.0942
# R-Squared (Between)             0.5701        -0.1474         0.1840           -0.0277
# R-Squared (Overall)             0.3970        -0.1124         0.1761           -0.0106
# F-statistic                     13.992         2.1744         2.1744            1.8069
# P-value (F-stat)                0.0000         0.0798         0.0798            0.1350
# =====================     ============   ============   ============   ===============
# Intercept                       6.2068        -0.9743                          -0.2173
#                               (2.3642)      (-0.6519)                        (-0.1241)
# CC                              15.068         38.060         38.060            35.636
#                               (0.4117)       (2.1313)       (2.1313)          (1.9448)
# FFR                             0.2180        -0.4912        -0.4912           -0.4164
#                               (0.1601)      (-0.7414)      (-0.7414)         (-0.6124)
# ROE                            -57.516         8.6866         8.6866            1.7077
#                              (-7.3621)       (1.0577)       (1.0577)          (0.2114)
# TA                             -0.3894        -0.4027        -0.4027           -0.4013
#                              (-0.0915)      (-0.1959)      (-0.1959)         (-0.1901)
# ======================= ============== ============== ============== =================
# Effects                                        Entity         Entity
# --------------------------------------------------------------------------------------
#
# T-stats reported in parentheses
#       Fixed Effects  Random Effects
# ID
# BAC       -0.953940       -0.417958
# BCS        8.750906        7.546422
# CTBI      -2.682882       -1.554807
# INDB      -2.720431       -1.632329
# JPM       -1.025270       -0.194072
# THFF      -2.968237       -1.888005
# TMP       -2.022188       -0.961046
# WASH      -1.815357       -0.714431
# WFC       -1.928120       -0.890798
# WSBC      -2.377867       -1.466204

# %%
# LM test for random effects versus OLS
n = pdata.index.levels[0].size
T = pdata.index.levels[1].size
D = np.kron(np.eye(n), np.ones(T)).T
e = pooled.resids
LM = (e.dot(D).dot(D.T).dot(e) / e.dot(e) - 1) ** 2 * n * T / 2 / (T - 1)
LM_pvalue = stats.chi2(1).sf(LM)
print("LM Test: chisq = {0}, df = 1, p-value = {1}".format(LM, LM_pvalue))
# Out:
# LM Test: chisq = 114.79958440058167, df = 1, p-value = 8.706685758573288e-27

# %%
# Hausman test for fixed versus random effects model
# null hypothesis: random effects model
psi = fixed.cov - random.cov.iloc[1:,1:]
diff = fixed.params - random.params[1:]
# psi = fixed1.cov.iloc[1:,1:] - random.cov.iloc[1:,1:]
# diff = fixed1.params[1:] - random.params[1:]
W = diff.dot(np.linalg.inv(psi)).dot(diff)
dof = random.params.size -1
pvalue = stats.chi2(dof).sf(W)
print("Hausman Test: chisq = {0}, df = {1}, p-value = {2}".format(W, dof, pvalue))
# Out:
# Hausman Test: chisq = 22.120244036394947, df = 4, p-value = 0.0001896713520889557

# %%
# panel robust hetero cov
fixed_robust = PanelOLS.from_formula('DE ~ 1 + ROE + TA + CC + FFR + EntityEffects', df).fit(cov_type='clustered',cluster_entity=True)
print(fixed_robust)
random_robust = RandomEffects.from_formula('DE ~ 1 + ROE + TA + CC + FFR', df).fit(cov_type='clustered',cluster_entity=True)
print(random_robust)
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                     DE   R-squared:                        0.1027
# Estimator:                   PanelOLS   R-squared (Between):             -0.1474
# No. Observations:                  90   R-squared (Within):               0.1027
# Date:                Wed, May 11 2022   R-squared (Overall):             -0.1124
# Time:                        22:34:27   Log-likelihood                   -142.60
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2.1744
# Entities:                          10   P-value                           0.0798
# Avg Obs:                       9.0000   Distribution:                    F(4,76)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             1.3805
#                                         P-value                           0.2487
# Time periods:                       9   Distribution:                    F(4,76)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept     -0.9743     3.0532    -0.3191     0.7505     -7.0553      5.1066
# CC             38.060     32.159     1.1835     0.2403     -25.990      102.11
# FFR           -0.4912     0.5263    -0.9332     0.3537     -1.5394      0.5571
# ROE            8.6866     11.731     0.7405     0.4613     -14.677      32.050
# TA            -0.4027     0.3858    -1.0437     0.2999     -1.1711      0.3657
# ==============================================================================
#
# F-test for Poolability: 32.040
# P-value: 0.0000
# Distribution: F(9,76)
#
# Included effects: Entity
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                     DE   R-squared:                        0.0784
# Estimator:              RandomEffects   R-squared (Between):             -0.0277
# No. Observations:                  90   R-squared (Within):               0.0942
# Date:                Wed, May 11 2022   R-squared (Overall):             -0.0106
# Time:                        22:34:27   Log-likelihood                   -150.05
# Cov. Estimator:             Clustered
#                                         F-statistic:                      1.8069
# Entities:                          10   P-value                           0.1350
# Avg Obs:                       9.0000   Distribution:                    F(4,85)
# Min Obs:                       9.0000
# Max Obs:                       9.0000   F-statistic (robust):             2.8472
#                                         P-value                           0.0288
# Time periods:                       9   Distribution:                    F(4,85)
# Avg Obs:                      10.0000
# Min Obs:                      10.0000
# Max Obs:                      10.0000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept     -0.2173     1.4869    -0.1462     0.8841     -3.1737      2.7391
# CC             35.636     29.858     1.1935     0.2360     -23.729      95.002
# FFR           -0.4164     0.4921    -0.8462     0.3998     -1.3947      0.5619
# ROE            1.7077     6.4577     0.2645     0.7921     -11.132      14.547
# TA            -0.4013     0.3257    -1.2322     0.2213     -1.0488      0.2462
# ==============================================================================

# %%
# compare fixed effects and random effects models
res3 = {'Fixed (Panel-Robust)':fixed_robust,'Random (Panel-Robust)':random_robust}
print(compare(res3))
# Out:
#                          Model Comparison
# ==================================================================
#                         Fixed (Panel-Robust) Random (Panel-Robust)
# ------------------------------------------------------------------
# Dep. Variable                             DE                    DE
# Estimator                           PanelOLS         RandomEffects
# No. Observations                          90                    90
# Cov. Est.                          Clustered             Clustered
# R-squared                             0.1027                0.0784
# R-Squared (Within)                    0.1027                0.0942
# R-Squared (Between)                  -0.1474               -0.0277
# R-Squared (Overall)                  -0.1124               -0.0106
# F-statistic                           2.1744                1.8069
# P-value (F-stat)                      0.0798                0.1350
# =====================            ===========       ===============
# Intercept                            -0.9743               -0.2173
#                                    (-0.3191)             (-0.1462)
# CC                                    38.060                35.636
#                                     (1.1835)              (1.1935)
# FFR                                  -0.4912               -0.4164
#                                    (-0.9332)             (-0.8462)
# ROE                                   8.6866                1.7077
#                                     (0.7405)              (0.2645)
# TA                                   -0.4027               -0.4013
#                                    (-1.0437)             (-1.2322)
# =======================        =============     =================
# Effects                               Entity
# ------------------------------------------------------------------
#
# T-stats reported in parentheses
